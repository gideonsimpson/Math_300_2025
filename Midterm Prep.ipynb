# %%
0.25 * (-2/3)^2 + 1/3 * (-2/3) - 1/4
# Out:
# -0.3611111111111111

# %%
sqrt(3)
# Out:
# 1.7320508075688772

# %%
1.732
# Out:
# 1.732

# %%
sin(1)
# Out:
# 0.8414709848078965

# %%
log(2)
# Out:
# 0.6931471805599453
